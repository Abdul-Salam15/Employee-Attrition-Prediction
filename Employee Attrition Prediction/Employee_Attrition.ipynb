# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Employee-Attrition.csv')
df

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    1470
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
plt.figure(figsize = (15, 5))
plt.rc("font", size=14)
sns.countplot(y = 'Attrition', data = df, palette='viridis')
plt.show()

# %%
plt.figure(figsize = (12, 5))
sns.countplot(data = df, x = 'Department', hue = 'Attrition', palette = 'hot')
plt.title('Attrition with respect to Department')
plt.show()

# %%
plt.figure(figsize= (12, 6))
sns.countplot(x = 'Gender', hue = 'Attrition', data = df, palette = 'viridis')
plt.show()

# %%
plt.figure(figsize = (12, 6))
sns.countplot(x='EducationField', hue='Attrition', data=df, palette='hot')
plt.title("Attrition w.r.t EducationField")
plt.xticks(rotation=30)
plt.show()

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
plt.figure(figsize= (12, 6))
sns.countplot(x = 'BusinessTravel', hue = 'Attrition', data = df, palette = 'deep')
plt.show()

# %%
plt.figure(figsize= (12, 6))
sns.countplot(x = 'JobRole', hue = 'Attrition', data = df, palette = 'dark')
plt.xticks(rotation = 45)
plt.show()

# %%
# age distribution
plt.figure(figsize= (12, 6))
sns.distplot(df['Age'])
plt.show()

# %%
# ordinal data in the dataset
ordinal_data = ['Education', 'JobInvolvement', 'JobSatisfaction', 'PerformanceRating', 
                'EnvironmentSatisfaction', 'RelationshipSatisfaction', 'WorkLifeBalance' ]
df[ordinal_data].head()
# Out:
#    Education  JobInvolvement  JobSatisfaction  PerformanceRating  \
# 0          2               3                4                  3
# 1          1               2                2                  4
# 2          2               2                3                  3
# 3          4               3                3                  3
# 4          1               3                2                  3
#
#    EnvironmentSatisfaction  RelationshipSatisfaction  WorkLifeBalance
# 0                        2                         1                1
# 1                        3                         4                3
# 2                        4                         2                3
# 3                        4                         3                3
# 4                        1                         4                3

# %%
# EDA of Education with respect to attrition
education_mapping = {1 : 'Below College', 2 : 'College', 3 : 'Bachelor', 4 : 'Master', 5 : 'Doctor'}
plt.figure(figsize = (12, 6))
sns.countplot(x = df['Education'].map(education_mapping), hue = 'Attrition', data = df, palette = 'hot')
plt.show()

# %%
# Target Variable(Attrition)
df['Attrition'] = df['Attrition'].replace({'No': 0, 'Yes':1})

# %%
#encode binary variables
df['OverTime'] = df['OverTime'].map({'No': 0, 'Yes':1})
df['Gender'] = df['Gender'].map({'Female' : 0, 'Male' : 1})
df['Over18'] = df['Over18'].map({'Y' : 1, "M" : 0})

# %%
df.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  \
# 0          2  Life Sciences              1               1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       0          94               3         2
#
#            JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 0  Sales Executive                4        Single           5993        19479
#
#    NumCompaniesWorked Over18  OverTime  PercentSalaryHike  PerformanceRating  \
# 0                   8      Y         1                 11                  3
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   int64
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoding_columns = ['BusinessTravel', 'Department', 'EducationField', 'JobRole', 'MaritalStatus']
label_encoders = {}
for column in encoding_columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# %%
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  \
# 0          2               1              1               1
# 1          1               1              1               2
# 2          2               4              1               4
# 3          4               1              1               5
# 4          1               3              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       0          94               3         2
# ...

# %%
X = df.drop(['Attrition', 'Over18'], axis = 1)
y = df['Attrition'].values

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
print(Counter(y))
random_over = RandomOverSampler(random_state = 42)
X_over, y_over = random_over.fit_resample(X,y)
print(Counter(y_over))
# Out:
# Counter({0: 1233, 1: 237})
# Counter({1: 1233, 0: 1233})

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve,roc_auc_score, classification_report
logistic_reg = LogisticRegression()
logistic_reg.fit(X_train, y_train)
prediction = logistic_reg.predict(X_test)
print("The Accuracy Score-> ", accuracy_score(y_test, prediction))
precision = precision_score(y_test, prediction)*100
recall = recall_score(y_test, prediction)*100
f1score = f1_score(y_test, prediction)*100
print(f"Precision Value-> {precision}%, Recall Value-> {recall}% F1 Score-> {f1score}%")
# Out:
# The Accuracy Score->  0.6497975708502024
# Precision Value-> 63.003663003663%, Recall Value-> 70.49180327868852% F1 Score-> 66.53771760154739%

# %%
fig = plt.figure(figsize = (12,6))
ax1 = fig.add_subplot(1,2,1)
cnf_matrix = confusion_matrix(y_test,prediction)
ax1 = sns.heatmap(pd.DataFrame(cnf_matrix), annot = True, cmap = 'Blues', fmt = 'd')
bottom, top = ax1.get_ylim()
ax1.set_ylim(bottom + 0.5, top - 0.5)
plt.xlabel('Predicted')
plt.ylabel('Expected')

ax2 = fig.add_subplot(1,2,2)
y_pred_proba = logistic_reg.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  prediction)
auc = roc_auc_score(y_test, prediction)
ax2 = plt.plot(fpr,tpr,label="data 1, auc="+str(auc))
plt.legend(loc=4)
plt.show()
